# %%
import cv2,os

data_path='/content/drive/MyDrive/DataSet/chest_xray/train'
categories=os.listdir(data_path)
labels=[i for i in range(len(categories))]

label_dict=dict(zip(categories,labels))

print(label_dict)
print(categories)
print(labels)
# Out:
# {'PNEUMONIA': 0, 'NORMAL': 1}
# ['PNEUMONIA', 'NORMAL']
# [0, 1]

# %%
import matplotlib.pyplot as plt

data_path = '/content/drive/MyDrive/DataSet/chest_xray/train'
categories = os.listdir(data_path)
labels = [i for i in range(len(categories))]

label_dict = dict(zip(categories, labels))  # empty dictionary
colors = ['red', 'blue', 'green', 'yellow', 'purple']

print("Label Dictionary:", label_dict)
print("Categories:", categories)
print("Labels:", labels)

# Print size of the dataset
dataset_size = sum(len(os.listdir(os.path.join(data_path, category))) for category in categories)
print("Size of the Train dataset:", dataset_size)

# Plot for the labels
plt.figure(figsize=(8, 6))
bar_plot = plt.bar(label_dict.keys(), [len(os.listdir(os.path.join(data_path, category))) for category in categories], color=colors)

for idx, rect in enumerate(bar_plot):
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, f'{height}', ha='center', va='bottom', color='black', fontweight='bold')

plt.xlabel('Categories')
plt.ylabel('Number of Images')
plt.title('Distribution of Images in Each Category')
plt.show()
# Out:
# Label Dictionary: {'PNEUMONIA': 0, 'NORMAL': 1}
# Categories: ['PNEUMONIA', 'NORMAL']
# Labels: [0, 1]
# Size of the Train dataset: 5242

# %%
data_path2='/content/drive/MyDrive/DataSet/chest_xray/test'
categories2=os.listdir(data_path)
labels2=[i for i in range(len(categories2))]

label_dict2=dict(zip(categories2,labels2)) #empty dictionary

print(label_dict2)
print(categories2)
print(labels2)
# Print size of the dataset
dataset_size = sum(len(os.listdir(os.path.join(data_path, category))) for category in categories)
print("Size of the test dataset:", dataset_size)
# Out:
# {'PNEUMONIA': 0, 'NORMAL': 1}
# ['PNEUMONIA', 'NORMAL']
# [0, 1]
# Size of the test dataset: 5242

# %%
# Plot for the labels
plt.figure(figsize=(8, 6))
bar_plot = plt.bar(label_dict.keys(), [len(os.listdir(os.path.join(data_path, category))) for category in categories], color=colors)
for idx, rect in enumerate(bar_plot):
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, f'{height}', ha='center', va='bottom', color='black', fontweight='bold')

plt.xlabel('Categories')
plt.ylabel('Number of Images')
plt.title('Distribution of Images in Each Category')
plt.show()
